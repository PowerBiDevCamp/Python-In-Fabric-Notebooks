# %%
import matplotlib.pyplot as plt

sales = { 
    "Apples": 30000,
    "Banana": 42000,
    "Carrots": 24000
}

sales_list = list(sales.values())
labels_list = list(sales.keys())

plt.figure(figsize=(3, 3))
plt.pie(sales_list, labels=labels_list)

plt.show()
# Out:
# StatementMeta(, 0eb6fe8e-3ea3-4f76-9cae-299e18ae9edc, 5, Finished, Available)

# %%
import matplotlib.pyplot as plt

sales = { "Apples": 30000, "Banana": 42000, "Carrots": 24000 }

sales_list = list(sales.values())
labels_list = list(sales.keys())

# Example themes: default, classic, dark_background, ggplot, _mpl-gallery, seaborn-v0_8
#plt.style.use('_mpl-gallery')

plt.figure(figsize=(6, 3))
plt.bar(labels_list, sales_list)

plt.show()
# Out:
# StatementMeta(, 0eb6fe8e-3ea3-4f76-9cae-299e18ae9edc, 6, Finished, Available)

# %%
import matplotlib.pyplot as plt

sales = { "Apples": 30000, "Banana": 42000, "Carrots": 24000 }

sales_list = list(sales.values())
labels_list = list(sales.keys())

figure = plt.figure(figsize=(6, 3))

# create and configure subplot
plot = figure.add_subplot()
plot.bar(labels_list, sales_list)
plot.yaxis.set_major_formatter('${x:,.0f}')
plot.set_title("Sample Bar Chart")

plt.show()
# Out:
# StatementMeta(, 0eb6fe8e-3ea3-4f76-9cae-299e18ae9edc, 8, Finished, Available)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter

sales = { "Apples": 30000, "Banana": 42000, "Carrots": 24000 }

sales_list = list(sales.values())
labels_list = list(sales.keys())

# create figure with 2 subplots - 1 row with 2 columns
fig, plots = plt.subplots(1, 2)

fig.set_figwidth(12)
fig.set_figheight(4)
plt.subplots_adjust(wspace=0.5)

plots[0].bar(labels_list, sales_list)
plots[0].set_title("Sample Column Chart")
plots[0].yaxis.set_major_formatter('${x:,.0f}')

plots[1].pie(sales_list, labels=labels_list)
plots[1].set_title("Sample Pie Chart")

plt.show()
# Out:
# StatementMeta(, 623e2f01-cdca-44d3-8e9b-704567d7ab8f, 157, Finished, Available)

# %%
import matplotlib.pyplot as plt

sales = {
    "Apples": 30000,
    "Banana": 42000,
    "Carrots": 24000
}

bar_list = range(len(sales)) 
sales_list = list(sales.values())
labels_list = list(sales.keys())

fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
#axs[0].pie(sales_list, labels=labels_list)
axs[1].bar(labels_list, sales_list)
axs[2].plot(labels_list, sales_list)
fig.suptitle('Categorical Plotting')
# Out:
# StatementMeta(, 623e2f01-cdca-44d3-8e9b-704567d7ab8f, 24, Finished, Available)
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
import numpy as np
import matplotlib.pyplot as plt

# create sample data arrays for x axis and y axis
x = np.linspace(0, 30, 100)
y = np.sin(x) * 2

# apply stlying
plt.style.use('_mpl-gallery')

# generate plot image
plt.plot(x, y, linewidth=1.5)
# Out:
# StatementMeta(, 623e2f01-cdca-44d3-8e9b-704567d7ab8f, 126, Finished, Available)

# %%
import matplotlib.pyplot as plt
import numpy as np
#plt.style.use('_mpl-gallery')

# make data:
x = 0.5 + np.arange(8)
y = [4.8, 5.5, 3.5, 4.6, 6.5, 6.6, 2.6, 3.0]

# plot
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
# Out:
# StatementMeta(, b846a947-4f82-40fc-8464-ce212537129a, 26, Finished, Available)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make the data
np.random.seed(3)
x = 4 + np.random.normal(0, 2, 24)
y = 4 + np.random.normal(0, 2, len(x))
# size and color:
sizes = np.random.uniform(15, 80, len(x))
colors = np.random.uniform(15, 80, len(x))

# plot
fig, ax = plt.subplots()

ax.scatter(x, y, s=sizes, c=colors, vmin=0, vmax=100)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
# Out:
# StatementMeta(, , , Waiting, )

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
x = np.arange(0, 10, 2)
ay = [1, 1.25, 2, 2.75, 3]
by = [1, 1, 1, 1, 1]
cy = [2, 1, 2, 1, 2]
y = np.vstack([ay, by, cy])

# plot
fig, ax = plt.subplots()

ax.stackplot(x, y)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
# Out:
# StatementMeta(, , , Waiting, )

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()
# Out:
# StatementMeta(, , , Waiting, )

# %%
import numpy as np
import matplotlib.pyplot as plt


plt.style.use('_mpl-gallery-nogrid')


# make data
x = [1, 2, 3, 4]
colors = plt.get_cmap('Blues')(np.linspace(0.2, 0.7, len(x)))

# plot
fig, ax = plt.subplots()
ax.pie(x, colors=colors, radius=3, center=(4, 4),
       wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
# Out:
# StatementMeta(, , , Waiting, )

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
np.random.seed(10)
D = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))

# plot
fig, ax = plt.subplots()
VP = ax.boxplot(D, positions=[2, 4, 6], widths=1.5, patch_artist=True,
                showmeans=False, showfliers=False,
                medianprops={"color": "white", "linewidth": 0.5},
                boxprops={"facecolor": "C0", "edgecolor": "white",
                          "linewidth": 0.5},
                whiskerprops={"color": "C0", "linewidth": 1.5},
                capprops={"color": "C0", "linewidth": 1.5})

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
# Out:
# StatementMeta(, , , Waiting, )

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)

fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos, labels=people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()
# Out:
# StatementMeta(, , , Waiting, )

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()
# Out:
# StatementMeta(, , , Waiting, )

# %%
import matplotlib.pyplot as plt

data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle('Categorical Plotting')
# Out:
# StatementMeta(, , , Waiting, )
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)
# Out:
# StatementMeta(, , , Waiting, )

# %%
import plotly.express as px
fig = px.bar(x=["a", "b", "c"], y=[1, 3, 2])
fig.show()
# Out:
# StatementMeta(, , , Waiting, )
# ...

# %%
import plotly.express as px
df = px.data.tips()
fig = px.histogram(df, x="total_bill")
fig.show()
# Out:
# StatementMeta(, , , Waiting, )
# ...

# %%
fig0, axs0 = plt.subplots(2, 1, figsize=(8, 2))
fig0.suptitle('Simple Formatting')

# A ``str``, using format string function syntax, can be used directly as a
# formatter.  The variable ``x`` is the tick value and the variable ``pos`` is
# tick position.  This creates a StrMethodFormatter automatically.
#setup(axs0[0], title="'{x} km'")
axs0[0].xaxis.set_major_formatter('{x} km')

# A function can also be used directly as a formatter. The function must take
# two arguments: ``x`` for the tick value and ``pos`` for the tick position,
# and must return a ``str``. This creates a FuncFormatter automatically.
#setup(axs0[1], title="lambda x, pos: str(x-5)")
axs0[1].xaxis.set_major_formatter(lambda x, pos: str(x-5))

fig0.tight_layout()
# Out:
# StatementMeta(, 623e2f01-cdca-44d3-8e9b-704567d7ab8f, 34, Finished, Available)
