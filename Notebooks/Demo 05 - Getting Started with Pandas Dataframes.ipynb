# %%
import pandas as pd

# Read a CSV into a Pandas DataFrame from e.g. a public blob store
CSV_URL = "https://github.com/PowerBiDevCamp/Python-In-Fabric-Notebooks/raw/main/CSV/Products.csv"
dataFrame  = pd.read_csv(CSV_URL)

mssparkutils.fs.put("Files/product_data/Products.json", dataFrame.to_json(), True)
mssparkutils.fs.put("Files/product_data/Products.xml", dataFrame.to_xml(), True)
# Out:
# StatementMeta(, fd48e0eb-f8f7-4a56-bc51-0bac17efd900, 6, Submitted, Running)
# True
