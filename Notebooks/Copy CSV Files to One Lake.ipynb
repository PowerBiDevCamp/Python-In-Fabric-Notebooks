# %%
import csv
import requests

# The API endpoint
CSV_URL = "https://github.com/PowerBiDevCamp/Python-In-Fabric-Notebooks/raw/main/CSV/Customers.csv"

with requests.get(CSV_URL, stream=True) as response:
    content = response.content.decode('utf-8-sig')
    mssparkutils.fs.put("Files/lenny/Customers.csv", content, True)
    print(content)
# Out:
# StatementMeta(, , , Waiting, )
# CustomerId,FirstName,LastName,CountryCode,City,BirthDate
# 1,Yolanda,Wagner,BE,Brussels,2/24/1969
# 2,Arnold,Harmon,GB,London,11/1/1943
# 3,Minh,Casey,IE,Limerick,11/24/1975
# 4,Russell,McIntyre,PT,Braga,8/5/1991
# 5,Angelina,Santiago,GB,London,8/22/1976
# 6,Sabrina,Conway,GB,Birmingham,6/25/1962
# 7,Jacqueline,Zimmerman,BE,Brussels,5/4/2001
# 8,Dewey,Francis,GB,Liverpool,1/10/1956
# 9,Haley,McDowell,BE,Brussels,4/25/1986
# 10,Brittany,Tate,GB,Liverpool,4/7/1989
# 11,Dario,Morse,PT,Porto,6/2/1966
# 12,Josh,Conrad,GB,Liverpool,10/18/1982
# 13,Coleman,Rios,GB,Birmingham,1/17/1950
# 14,Shari,Nieves,GB,Liverpool,5/4/1982
# 15,Keri,Reyes,GB,London,2/9/1994
# 16,Lacy,Cross,BE,Antwerp,4/3/1997
# 17,Willie,Bonner,GB,Liverpool,8/2/1949
# 18,Silvia,Justice,GB,Liverpool,2/3/1965
# 19,Jody,Vinson,BE,Brussels,4/6/1960
# 20,Clifford,Kent,GB,Liverpool,11/14/1989
# 21,Rafael,Garner,PT,Lisbon,8/27/1948
# 22,Leigh,Lott,PT,Lisbon,3/12/1962
# ...
