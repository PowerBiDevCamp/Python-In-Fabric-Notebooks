# %%
message = "And now for something completely different"
print(message)
# Out:
# StatementMeta(, 7d95b758-b40f-48db-91ac-dabb8b9d2788, 3, Finished, Available)
# True

# %%
message = "And now for something completely different"
file_path = "Files/demo1/hello.txt"
mssparkutils.fs.put(file_path, message, True)
# Out:
# StatementMeta(, df04b68f-8f98-46dd-9dd0-c5a60fdb8a3c, 4, Finished, Available)
# True
